# %%
import pandas as pd

# %%
dataF = pd.read_csv("wine.csv")

# %%
dataF
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataF.shape
# Out:
# (1599, 12)

# %%
dataF.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dataF=dataF[dataF["citric acid"]!=0]
dataF
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataF1 = dataF.drop(["quality"], axis = 1)

# %%
dataF1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataF1.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
dataF["quality"]=dataF["quality"].map({"bad":0,"good":1})
print(dataF["quality"])
# Out:
# 2       0
# 3       1
# 6       0
# 8       1
# 9       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: quality, Length: 1467, dtype: int64
# C:\Users\User\AppData\Local\Temp/ipykernel_27260/2319630596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataF["quality"]=dataF["quality"].map({"bad":0,"good":1})

# %%
dataF.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1467.000000       1467.000000  1467.000000     1467.000000
# mean        8.438582          0.513033     0.295358        2.565815
# std         1.748852          0.171945     0.184819        1.449658
# min         4.600000          0.120000     0.010000        0.900000
# 25%         7.200000          0.380000     0.140000        1.900000
# 50%         8.000000          0.500000     0.280000        2.200000
# 75%         9.400000          0.620000     0.440000        2.600000
# max        15.900000          1.240000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1467.000000          1467.000000           1467.000000  1467.000000
# mean      0.087835            15.926380             47.768916     0.996821
# std       0.048318            10.438805             33.585820     0.001867
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X = dataF.iloc[:, :-1]
y = dataF.iloc[:, -1]

scaler = MinMaxScaler()

scaler.fit(X)

X_scaled = scaler.transform(X)

X_scaled
# Out:
# array([[0.28318584, 0.57142857, 0.03030303, ..., 0.44827586, 0.19161677,
#         0.21538462],
#        [0.5840708 , 0.14285714, 0.55555556, ..., 0.36206897, 0.1497006 ,
#         0.21538462],
#        [0.2920354 , 0.42857143, 0.05050505, ..., 0.48275862, 0.07784431,
#         0.15384615],
#        ...,
#        [0.15044248, 0.34821429, 0.12121212, ..., 0.5862069 , 0.25149701,
#         0.4       ],
#        [0.11504425, 0.46875   , 0.11111111, ..., 0.71551724, 0.22754491,
#         0.27692308],
#        [0.12389381, 0.16964286, 0.46464646, ..., 0.56034483, 0.19760479,
#         0.4       ]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(dataF[list(dataF1.columns)],
                                                    dataF["quality"],test_size=0.25,
                                                    random_state=0)

# %%
print("Y_train:",Y_train.shape)
print("X_train:",X_train.shape)
X_test
Y_test
# Out:
# Y_train: (1100,)
# X_train: (1100, 11)
# 395     1
# 1047    0
# 1052    0
# 1120    1
# 840     1
#        ..
# 889     0
# 1598    1
# 1515    1
# 1521    0
# 867     1
# Name: quality, Length: 367, dtype: int64

# %%
X_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 395            12.0             0.370         0.76            4.20      0.066
# 1047            7.1             0.430         0.17            1.80      0.082
# 1052            5.6             0.605         0.05            2.40      0.073
# 1120            7.9             0.540         0.34            2.50      0.076
# 840            11.1             0.420         0.47            2.65      0.085
# ...             ...               ...          ...             ...        ...
# 889            10.7             0.900         0.34            6.60      0.112
# 1598            6.0             0.310         0.47            3.60      0.067
# 1515            6.9             0.840         0.21            4.10      0.074
# 1521            6.9             0.480         0.20            1.90      0.082
# 867             6.9             0.510         0.23            2.00      0.072
#
# ...

# %%
Y_test
# Out:
# 395     1
# 1047    0
# 1052    0
# 1120    1
# 840     1
#        ..
# 889     0
# 1598    1
# 1515    1
# 1521    0
# 867     1
# Name: quality, Length: 367, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler()
